# %%
import pandas as pd
import matplotlib as plt

# %%
#read csv and print dataframe
csv = "Crime_Data_from_2020_to_Present.csv"
crime_data = pd.read_csv(csv)
crime_data.head()
# Out:
#        DR_NO       Date Rptd        DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0   10304468   1/8/2020 0:00   1/8/2020 0:00      2230     3    Southwest
# 1  190101086   1/2/2020 0:00   1/1/2020 0:00       330     1      Central
# 2  200110444  4/14/2020 0:00  2/13/2020 0:00      1200     1      Central
# 3  191501505   1/1/2020 0:00   1/1/2020 0:00      1730    15  N Hollywood
# 4  191921269   1/1/2020 0:00   1/1/2020 0:00       415    19      Mission
#
#    Rpt Dist No  Part 1-2  Crm Cd  \
# 0          377         2     624
# 1          163         2     624
# 2          155         2     845
# 3         1543         2     745
# 4         1998         2     740
#
#                                          Crm Cd Desc  ... Status  \
# 0                           BATTERY - SIMPLE ASSAULT  ...     AO
# 1                           BATTERY - SIMPLE ASSAULT  ...     IC
# 2          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE  ...     AA
# ...

# %%
#remove miscellaneous columns
clean_crime_data = crime_data.drop(['DR_NO',
                                   'AREA',
                                   'Rpt Dist No',
                                   'Part 1-2',
                                   'Crm Cd Desc',
                                   'Status',
                                   'Status Desc',
                                   'Crm Cd 1',
                                   'Crm Cd 2',
                                   'Crm Cd 3',
                                   'Crm Cd 4',
                                   'LOCATION',
                                    'Cross Street',
                                   'Premis Cd',
                                   'Premis Desc',
                                   'Weapon Used Cd',
                                   'Weapon Desc',
                                   'Mocodes',
                                   'Date Rptd'], 
                                   axis=1)
clean_crime_data.head()
# Out:
#          DATE OCC  TIME OCC    AREA NAME  Crm Cd  Vict Age Vict Sex  \
# 0   1/8/2020 0:00      2230    Southwest     624        36        F
# 1   1/1/2020 0:00       330      Central     624        25        M
# 2  2/13/2020 0:00      1200      Central     845         0        X
# 3   1/1/2020 0:00      1730  N Hollywood     745        76        F
# 4   1/1/2020 0:00       415      Mission     740        31        X
#
#   Vict Descent      LAT       LON
# 0            B  34.0141 -118.2978
# 1            H  34.0459 -118.2545
# 2            X  34.0448 -118.2474
# 3            W  34.1685 -118.4019
# 4            X  34.2198 -118.4468

# %%
#extract month and year from "DATE OCC"
clean_crime_data["Year of Occurrence"] = pd.DatetimeIndex(clean_crime_data["DATE OCC"]).year
clean_crime_data["Month of Occurrence"] = pd.DatetimeIndex(clean_crime_data["DATE OCC"]).month
clean_crime_data.head()
# Out:
#          DATE OCC  TIME OCC    AREA NAME  Crm Cd  Vict Age Vict Sex  \
# 0   1/8/2020 0:00      2230    Southwest     624        36        F
# 1   1/1/2020 0:00       330      Central     624        25        M
# 2  2/13/2020 0:00      1200      Central     845         0        X
# 3   1/1/2020 0:00      1730  N Hollywood     745        76        F
# 4   1/1/2020 0:00       415      Mission     740        31        X
#
#   Vict Descent      LAT       LON  Year of Occurrence  Month of Occurrence
# 0            B  34.0141 -118.2978                2020                    1
# 1            H  34.0459 -118.2545                2020                    1
# 2            X  34.0448 -118.2474                2020                    2
# 3            W  34.1685 -118.4019                2020                    1
# 4            X  34.2198 -118.4468                2020                    1

# %%
#remove 2023 data from dataset
crime_2020_to_2022 = clean_crime_data.loc[clean_crime_data["Year of Occurrence"] != 2023]
crime_2020_to_2022.head()
# Out:
#          DATE OCC  TIME OCC    AREA NAME  Crm Cd  Vict Age Vict Sex  \
# 0   1/8/2020 0:00      2230    Southwest     624        36        F
# 1   1/1/2020 0:00       330      Central     624        25        M
# 2  2/13/2020 0:00      1200      Central     845         0        X
# 3   1/1/2020 0:00      1730  N Hollywood     745        76        F
# 4   1/1/2020 0:00       415      Mission     740        31        X
#
#   Vict Descent      LAT       LON  Year of Occurrence  Month of Occurrence
# 0            B  34.0141 -118.2978                2020                    1
# 1            H  34.0459 -118.2545                2020                    1
# 2            X  34.0448 -118.2474                2020                    2
# 3            W  34.1685 -118.4019                2020                    1
# 4            X  34.2198 -118.4468                2020                    1
